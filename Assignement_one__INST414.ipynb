# %% [markdown]
# <a href="https://colab.research.google.com/github/Atarazona11/assignment_one/blob/main/Assignement_one__INST414.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Install the pandas and requests library
#   to be able to pull the data from the movies API

# %%
pip install requests

# %%
import requests
import pandas as pd

# %%
api_key = "2d2f69219a75f9ff0f2ddf63c079897d"
link = "https://api.themoviedb.org/3/movie/top_rated?api_key=2d2f69219a75f9ff0f2ddf63c079897d&language=en-US&page=1"
response = requests.get(link)

# %%
print(response.status_code)
# Out:
# 200

# %%
resp_object = response.json()
print(resp_object)
# Out:
# {'page': 1, 'results': [{'adult': False, 'backdrop_path': '/wPU78OPN4BYEgWYdXyg0phMee64.jpg', 'genre_ids': [18, 80], 'id': 278, 'original_language': 'en', 'original_title': 'The Shawshank Redemption', 'overview': 'Framed in the 1940s for the double murder of his wife and her lover, upstanding banker Andy Dufresne begins a new life at the Shawshank prison, where he puts his accounting skills to work for an amoral warden. During his long stretch in prison, Dufresne comes to be admired by the other inmates -- including an older prisoner named Red -- for his integrity and unquenchable sense of hope.', 'popularity': 63.807, 'poster_path': '/q6y0Go1tsGEsmtFryDOJo3dEmqu.jpg', 'release_date': '1994-09-23', 'title': 'The Shawshank Redemption', 'video': False, 'vote_average': 8.7, 'vote_count': 21326}, {'adult': False, 'backdrop_path': '/90ez6ArvpO8bvpyIngBuwXOqJm5.jpg', 'genre_ids': [35, 18, 10749], 'id': 19404, 'original_language': 'hi', 'original_title': 'दिलवाले दुल्हनिया ले जायेंगे', 'ove
# ...

# %%
response.json()
# Out:
# {'page': 1,
#  'results': [{'adult': False,
#    'backdrop_path': '/wPU78OPN4BYEgWYdXyg0phMee64.jpg',
#    'genre_ids': [18, 80],
#    'id': 278,
#    'original_language': 'en',
#    'original_title': 'The Shawshank Redemption',
#    'overview': 'Framed in the 1940s for the double murder of his wife and her lover, upstanding banker Andy Dufresne begins a new life at the Shawshank prison, where he puts his accounting skills to work for an amoral warden. During his long stretch in prison, Dufresne comes to be admired by the other inmates -- including an older prisoner named Red -- for his integrity and unquenchable sense of hope.',
#    'popularity': 63.807,
#    'poster_path': '/q6y0Go1tsGEsmtFryDOJo3dEmqu.jpg',
#    'release_date': '1994-09-23',
#    'title': 'The Shawshank Redemption',
#    'video': False,
#    'vote_average': 8.7,
#    'vote_count': 21326},
#   {'adult': False,
#    'backdrop_path': '/90ez6ArvpO8bvpyIngBuwXOqJm5.jpg',
#    'genre_ids': [35, 18, 10749],
# ...

# %%
response.json()["results"]
# Out:
# [{'adult': False,
#   'backdrop_path': '/wPU78OPN4BYEgWYdXyg0phMee64.jpg',
#   'genre_ids': [18, 80],
#   'id': 278,
#   'original_language': 'en',
#   'original_title': 'The Shawshank Redemption',
#   'overview': 'Framed in the 1940s for the double murder of his wife and her lover, upstanding banker Andy Dufresne begins a new life at the Shawshank prison, where he puts his accounting skills to work for an amoral warden. During his long stretch in prison, Dufresne comes to be admired by the other inmates -- including an older prisoner named Red -- for his integrity and unquenchable sense of hope.',
#   'popularity': 63.807,
#   'poster_path': '/q6y0Go1tsGEsmtFryDOJo3dEmqu.jpg',
#   'release_date': '1994-09-23',
#   'title': 'The Shawshank Redemption',
#   'video': False,
#   'vote_average': 8.7,
#   'vote_count': 21326},
#  {'adult': False,
#   'backdrop_path': '/90ez6ArvpO8bvpyIngBuwXOqJm5.jpg',
#   'genre_ids': [35, 18, 10749],
#   'id': 19404,
#   'original_language': 'hi',
# ...

# %%
data = pd.DataFrame(response.json()["results"])[['id','title','overview','popularity','release_date','vote_average','vote_count']]

# %%
for i in range(1, 429):
    response = requests.get("https://api.themoviedb.org/3/movie/top_rated?api_key=2d2f69219a75f9ff0f2ddf63c079897d&language=en-US&page={}".format(i))
    temp_df = pd.DataFrame(response.json()["results"])[['id','title','overview','popularity','release_date','vote_average','vote_count']]
    data.append(temp_df, ignore_index=False)
